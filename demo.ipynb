# %%
import re

# %%
l_match = re.finditer(r'[a-z\sA-Z]+', 'Loveen is a tired person. Poor Loveen')

# %%
l_match

# %%
for m in l_match:
    print(m)
# Out:
# <re.Match object; span=(0, 24), match='Loveen is a tired person'>
# <re.Match object; span=(25, 37), match=' Poor Loveen'>
